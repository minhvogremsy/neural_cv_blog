# %%
import argparse
import os

import onnx
import onnxsim
import torch

from nanodet.model.arch import build_model
from nanodet.util import Logger, cfg, load_config, load_model_weight

# %%
def generate_ouput_names(head_cfg):
    cls_names, dis_names = [], []
    for stride in head_cfg.strides:
        cls_names.append("cls_pred_stride_{}".format(stride))
        dis_names.append("dis_pred_stride_{}".format(stride))
    return cls_names + dis_names

# %%
def main(config, model_path, output_path, input_shape=(320, 320)):
    logger = Logger(-1, config.save_dir, False)
    model = build_model(config.model)
    checkpoint = torch.load(model_path, map_location=lambda storage, loc: storage)
    load_model_weight(model, checkpoint, logger)
    if config.model.arch.backbone.name == "RepVGG":
        deploy_config = config.model
        deploy_config.arch.backbone.update({"deploy": True})
        deploy_model = build_model(deploy_config)
        from nanodet.model.backbone.repvgg import repvgg_det_model_convert

        model = repvgg_det_model_convert(model, deploy_model)
    dummy_input = torch.autograd.Variable(
        torch.randn(1, 3, input_shape[0], input_shape[1])
    )

    torch.onnx.export(
        model,
        dummy_input,
        output_path,
        verbose=True,
        keep_initializers_as_inputs=True,
        opset_version=11,
        input_names=["data"],
        output_names=["output"],
    )
    logger.log("finished exporting onnx ")

    logger.log("start simplifying onnx ")
    input_data = {"data": dummy_input.detach().cpu().numpy()}
    model_sim, flag = onnxsim.simplify(output_path, input_data=input_data)
    if flag:
        onnx.save(model_sim, output_path)
        logger.log("simplify onnx successfully")
    else:
        logger.log("simplify onnx failed")

# %%
cfg_path = "nanodet-plus-m_320.yml"
model_path = "model_best.ckpt"
out_path = 'out.onnx'
input_shape = None
load_config(cfg, cfg_path)
if input_shape is None:
        input_shape = cfg.data.train.input_size
else:
        input_shape = tuple(map(int, input_shape.split(",")))
        assert len(input_shape) == 2
if model_path is None:
        model_path = os.path.join(cfg.save_dir, "model_best/model_best.ckpt")
main(cfg, model_path, out_path, input_shape)
print("Model saved to:", out_path)
# Out:
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet-Plus Head.
# C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:18: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   channels_per_group = num_channels // groups
# [root][04-25 08:31:03]INFO:finished exporting onnx
# [root][04-25 08:31:03]INFO:finished exporting onnx
# [root][04-25 08:31:03]INFO:start simplifying onnx
# [root][04-25 08:31:03]INFO:start simplifying onnx
# graph(%data : Float(1, 3, 320, 320, strides=[307200, 102400, 320, 1], requires_grad=0, device=cpu),
#       %head.gfl_cls.0.weight : Float(34, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=1, device=cpu),
#       %head.gfl_cls.0.bias : Float(34, strides=[1], requires_grad=1, device=cpu),
#       %head.gfl_cls.1.weight : Float(34, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=1, device=cpu),
#       %head.gfl_cls.1.bias : Float(34, strides=[1], requires_grad=1, device=cpu),
#       %head.gfl_cls.2.weight : Float(34, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=1, device=cpu),
#       %head.gfl_cls.2.bias : Float(34, strides=[1], requires_grad=1, device=cpu),
#       %head.gfl_cls.3.weight : Float(34, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=1, device=cpu),
#       %head.gfl_cls.3.bias : Float(34, strides=[1], requires_grad=1, device=cpu),
#       %1532 : Float(24, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=0, device=cpu),
#       %1533 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %1535 : Float(24, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1536 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %1538 : Float(58, 24, 1, 1, strides=[24, 1, 1, 1], requires_grad=0, device=cpu),
#       %1539 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1541 : Float(58, 24, 1, 1, strides=[24, 1, 1, 1], requires_grad=0, device=cpu),
#       %1542 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1544 : Float(58, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1545 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1547 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %1548 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1550 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %1551 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1553 : Float(58, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1554 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1556 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %1557 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1559 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %1560 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1562 : Float(58, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1563 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1565 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %1566 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1568 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %1569 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1571 : Float(58, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1572 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1574 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %1575 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %1577 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1578 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1580 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1581 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1583 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1584 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1586 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1587 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1589 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1590 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1592 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1593 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1595 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1596 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1598 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1599 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1601 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1602 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1604 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1605 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1607 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1608 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1610 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1611 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1613 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1614 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1616 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1617 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1619 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1620 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1622 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1623 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1625 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1626 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1628 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1629 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1631 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1632 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1634 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1635 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1637 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1638 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1640 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1641 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1643 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1644 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1646 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1647 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1649 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1650 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1652 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1653 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1655 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1656 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1658 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1659 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1661 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1662 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1664 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1665 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1667 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1668 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1670 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1671 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1673 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1674 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1676 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1677 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1679 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1680 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1682 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1683 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1685 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1686 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1688 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1689 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1691 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1692 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1694 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1695 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1697 : Float(96, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1698 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1700 : Float(96, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1701 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1703 : Float(96, 464, 1, 1, strides=[464, 1, 1, 1], requires_grad=0, device=cpu),
#       %1704 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1706 : Float(48, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %1707 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1709 : Float(48, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1710 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1712 : Float(48, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1713 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1715 : Float(48, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1716 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1718 : Float(192, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1719 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1721 : Float(96, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %1722 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1724 : Float(48, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %1725 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1727 : Float(48, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1728 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1730 : Float(48, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1731 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1733 : Float(48, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1734 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1736 : Float(192, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1737 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1739 : Float(96, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %1740 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1742 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1743 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1745 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1746 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1748 : Float(48, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %1749 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1751 : Float(48, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1752 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1754 : Float(48, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1755 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1757 : Float(48, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1758 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1760 : Float(192, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1761 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1763 : Float(96, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %1764 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1766 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1767 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1769 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1770 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1772 : Float(48, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %1773 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1775 : Float(48, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1776 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1778 : Float(48, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1779 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1781 : Float(48, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1782 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %1784 : Float(192, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1785 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %1787 : Float(96, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %1788 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1790 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1791 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1793 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1794 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1796 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1797 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1799 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1800 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1802 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1803 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1805 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1806 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1808 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1809 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1811 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1812 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1814 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1815 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1817 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1818 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1820 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1821 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1823 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1824 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1826 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1827 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1829 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1830 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1832 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1833 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1835 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1836 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1838 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1839 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1841 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1842 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1844 : Float(96, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %1845 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1847 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1848 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1849 : Float(4, strides=[1], requires_grad=0, device=cpu),
#       %1850 : Float(4, strides=[1], requires_grad=0, device=cpu)):
#   %input.4 : Float(1, 24, 160, 160, strides=[614400, 25600, 160, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%data, %1532, %1533) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %890 : Float(1, 24, 160, 160, strides=[614400, 25600, 160, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.4) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.8 : Float(1, 24, 80, 80, strides=[153600, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%890) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:797:0
#   %input.16 : Float(1, 24, 40, 40, strides=[38400, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=24, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%input.8, %1535, %1536) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %input.24 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.16, %1538, %1539) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %896 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.24) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.32 : Float(1, 58, 80, 80, strides=[371200, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.8, %1541, %1542) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %899 : Float(1, 58, 80, 80, strides=[371200, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.32) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.40 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=58, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%899, %1544, %1545) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %input.48 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.40, %1547, %1548) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %904 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.48) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %out : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%896, %904) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:97:0
#   %906 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=  1   2  58  40  40 [ CPULongType{5} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %907 : Float(1, 2, 58, 40, 40, strides=[185600, 92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%out, %906) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %908 : Float(1, 58, 2, 40, 40, strides=[185600, 3200, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%907) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:23:0
#   %909 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  40  40 [ CPULongType{4} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %910 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%908, %909) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %911 : Long(4, strides=[1], device=cpu) = onnx::Shape(%910) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %912 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %913 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%911, %912) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %914 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %915 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %916 : Long(1, strides=[1], device=cpu) = onnx::Add(%913, %915) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %917 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %918 : Long(1, strides=[1], device=cpu) = onnx::Div(%916, %917) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %919 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %920 : Long(1, strides=[1], device=cpu) = onnx::Mul(%918, %919) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %921 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%910, %914, %920, %912) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %922 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %923 : Long(1, strides=[1], device=cpu) = onnx::Mul(%918, %922) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %924 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%910, %920, %923, %912) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %input.56 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%924, %1550, %1551) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %927 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.56) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.64 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=58, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%927, %1553, %1554) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %input.72 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.64, %1556, %1557) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %932 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.72) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %out.3 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%921, %932) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:95:0
#   %934 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=  1   2  58  40  40 [ CPULongType{5} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %935 : Float(1, 2, 58, 40, 40, strides=[185600, 92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%out.3, %934) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %936 : Float(1, 58, 2, 40, 40, strides=[185600, 3200, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%935) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:23:0
#   %937 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  40  40 [ CPULongType{4} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %938 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%936, %937) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %939 : Long(4, strides=[1], device=cpu) = onnx::Shape(%938) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %940 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %941 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%939, %940) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %942 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %943 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %944 : Long(1, strides=[1], device=cpu) = onnx::Add(%941, %943) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %945 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %946 : Long(1, strides=[1], device=cpu) = onnx::Div(%944, %945) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %947 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %948 : Long(1, strides=[1], device=cpu) = onnx::Mul(%946, %947) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %949 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%938, %942, %948, %940) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %950 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %951 : Long(1, strides=[1], device=cpu) = onnx::Mul(%946, %950) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %952 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%938, %948, %951, %940) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %input.80 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%952, %1559, %1560) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %955 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.80) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.88 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=58, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%955, %1562, %1563) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %input.96 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.88, %1565, %1566) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %960 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.96) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %out.7 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%949, %960) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:95:0
#   %962 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=  1   2  58  40  40 [ CPULongType{5} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %963 : Float(1, 2, 58, 40, 40, strides=[185600, 92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%out.7, %962) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %964 : Float(1, 58, 2, 40, 40, strides=[185600, 3200, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%963) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:23:0
#   %965 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  40  40 [ CPULongType{4} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %966 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%964, %965) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %967 : Long(4, strides=[1], device=cpu) = onnx::Shape(%966) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %968 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %969 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%967, %968) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %970 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %971 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %972 : Long(1, strides=[1], device=cpu) = onnx::Add(%969, %971) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %973 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %974 : Long(1, strides=[1], device=cpu) = onnx::Div(%972, %973) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %975 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %976 : Long(1, strides=[1], device=cpu) = onnx::Mul(%974, %975) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %977 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%966, %970, %976, %968) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %978 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %979 : Long(1, strides=[1], device=cpu) = onnx::Mul(%974, %978) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %980 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%966, %976, %979, %968) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %input.104 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%980, %1568, %1569) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %983 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.104) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.112 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=58, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%983, %1571, %1572) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %input.120 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.112, %1574, %1575) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %988 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.120) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %out.11 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%977, %988) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:95:0
#   %990 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=  1   2  58  40  40 [ CPULongType{5} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %991 : Float(1, 2, 58, 40, 40, strides=[185600, 92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%out.11, %990) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %992 : Float(1, 58, 2, 40, 40, strides=[185600, 3200, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%991) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:23:0
#   %993 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  40  40 [ CPULongType{4} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %input.124 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%992, %993) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %input.132 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%input.124, %1577, %1578) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %input.140 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.132, %1580, %1581) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %999 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.140) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.148 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.124, %1583, %1584) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1002 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.148) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.156 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%1002, %1586, %1587) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %input.164 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.156, %1589, %1590) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1007 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.164) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %out.15 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%999, %1007) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:97:0
#   %1009 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %1010 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%out.15, %1009) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %1011 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%1010) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:23:0
#   %1012 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %1013 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%1011, %1012) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %1014 : Long(4, strides=[1], device=cpu) = onnx::Shape(%1013) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1015 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1016 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%1014, %1015) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1017 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1018 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1019 : Long(1, strides=[1], device=cpu) = onnx::Add(%1016, %1018) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1020 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1021 : Long(1, strides=[1], device=cpu) = onnx::Div(%1019, %1020) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1022 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1023 : Long(1, strides=[1], device=cpu) = onnx::Mul(%1021, %1022) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1024 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%1013, %1017, %1023, %1015) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1025 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1026 : Long(1, strides=[1], device=cpu) = onnx::Mul(%1021, %1025) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1027 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%1013, %1023, %1026, %1015) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %input.172 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1027, %1592, %1593) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1030 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.172) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.180 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1030, %1595, %1596) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %input.188 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input.180, %1598, %1599) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1035 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.188) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %out.19 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%1024, %1035) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:95:0
#   %1037 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %1038 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%out.19, %1037) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:21:0
#   %1039 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%1038) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:23:0
#   %1040 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %1041 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%1039, %1040) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:26:0
#   %1042 : Long(4, strides=[1], device=cpu) = onnx::Shape(%1041) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
#   %1043 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\backbone\shufflenetv2.py:94:0
# ...
#   %1448 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1449 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1450 : Long(2, strides=[1], device=cpu) = onnx::Slice(%1446, %1448, %1449, %1447) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1451 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1452 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%1450, %1451) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1453 : Float(1, 34, 1600, strides=[54400, 1600, 1], requires_grad=1, device=cpu) = onnx::Reshape(%1445, %1452) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %input.776 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%1391, %1814, %1815) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1456 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.776) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.784 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1456, %1817, %1818) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1459 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.784) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.792 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%1459, %1820, %1821) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1462 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.792) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.800 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1462, %1823, %1824) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1465 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.800) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %output.3 : Float(1, 34, 20, 20, strides=[13600, 400, 20, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1465, %head.gfl_cls.1.weight, %head.gfl_cls.1.bias) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1467 : Float(1, 2, 20, 20, strides=[13600, 400, 20, 1], requires_grad=1, device=cpu), %1468 : Float(1, 32, 20, 20, strides=[13600, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[2, 32]](%output.3) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\_tensor.py:574:0
#   %1469 : Float(1, 2, 20, 20, strides=[800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%1467) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:515:0
#   %1470 : Float(1, 34, 20, 20, strides=[13600, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%1469, %1468) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:516:0
#   %1471 : Long(4, strides=[1], device=cpu) = onnx::Shape(%1470) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1472 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1473 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1474 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1475 : Long(2, strides=[1], device=cpu) = onnx::Slice(%1471, %1473, %1474, %1472) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1476 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1477 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%1475, %1476) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1478 : Float(1, 34, 400, strides=[13600, 400, 1], requires_grad=1, device=cpu) = onnx::Reshape(%1470, %1477) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %input.808 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%1415, %1826, %1827) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1481 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.808) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.816 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1481, %1829, %1830) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1484 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.816) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.824 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%1484, %1832, %1833) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1487 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.824) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.832 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1487, %1835, %1836) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1490 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.832) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %output.7 : Float(1, 34, 10, 10, strides=[3400, 100, 10, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1490, %head.gfl_cls.2.weight, %head.gfl_cls.2.bias) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1492 : Float(1, 2, 10, 10, strides=[3400, 100, 10, 1], requires_grad=1, device=cpu), %1493 : Float(1, 32, 10, 10, strides=[3400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[2, 32]](%output.7) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\_tensor.py:574:0
#   %1494 : Float(1, 2, 10, 10, strides=[200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%1492) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:515:0
#   %1495 : Float(1, 34, 10, 10, strides=[3400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%1494, %1493) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:516:0
#   %1496 : Long(4, strides=[1], device=cpu) = onnx::Shape(%1495) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1497 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1498 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1499 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1500 : Long(2, strides=[1], device=cpu) = onnx::Slice(%1496, %1498, %1499, %1497) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1501 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1502 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%1500, %1501) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1503 : Float(1, 34, 100, strides=[3400, 100, 1], requires_grad=1, device=cpu) = onnx::Reshape(%1495, %1502) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %input.840 : Float(1, 96, 5, 5, strides=[2400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%input.736, %1838, %1839) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1506 : Float(1, 96, 5, 5, strides=[2400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.840) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.848 : Float(1, 96, 5, 5, strides=[2400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1506, %1841, %1842) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1509 : Float(1, 96, 5, 5, strides=[2400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.848) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.856 : Float(1, 96, 5, 5, strides=[2400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%1509, %1844, %1845) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1512 : Float(1, 96, 5, 5, strides=[2400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.856) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %input.864 : Float(1, 96, 5, 5, strides=[2400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1512, %1847, %1848) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1515 : Float(1, 96, 5, 5, strides=[2400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%input.864) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\functional.py:1616:0
#   %output.11 : Float(1, 34, 5, 5, strides=[850, 25, 5, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1515, %head.gfl_cls.3.weight, %head.gfl_cls.3.bias) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\nn\modules\conv.py:443:0
#   %1517 : Float(1, 2, 5, 5, strides=[850, 25, 5, 1], requires_grad=1, device=cpu), %1518 : Float(1, 32, 5, 5, strides=[850, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[2, 32]](%output.11) # C:\Users\biaspaltsau_aa\Anaconda3\envs\torch\lib\site-packages\torch\_tensor.py:574:0
#   %1519 : Float(1, 2, 5, 5, strides=[50, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%1517) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:515:0
#   %1520 : Float(1, 34, 5, 5, strides=[850, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%1519, %1518) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:516:0
#   %1521 : Long(4, strides=[1], device=cpu) = onnx::Shape(%1520) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1522 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1523 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1524 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1525 : Long(2, strides=[1], device=cpu) = onnx::Slice(%1521, %1523, %1524, %1522) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1526 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]() # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1527 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%1525, %1526) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1528 : Float(1, 34, 25, strides=[850, 25, 1], requires_grad=1, device=cpu) = onnx::Reshape(%1520, %1527) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:517:0
#   %1529 : Float(1, 34, 2125, strides=[72250, 2125, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=2](%1453, %1478, %1503, %1528) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:518:0
#   %output : Float(1, 2125, 34, strides=[72250, 1, 2125], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%1529) # C:\Users\biaspaltsau_aa\python_folder\NANODET\nanodet\nanodet\model\head\nanodet_plus_head.py:518:0
#   return (%output)
# [root][04-25 08:31:04]INFO:simplify onnx successfully
# [root][04-25 08:31:04]INFO:simplify onnx successfully
# Model saved to: out.onnx
